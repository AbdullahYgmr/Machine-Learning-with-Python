# %% [markdown]
# ## Hierarchy_Unsupervised-Learning

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

X, _ = make_blobs(n_samples=300, random_state=42, cluster_std=0.7, centers=4)
plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])
plt.title("Example Data")
# Out:
# Text(0.5, 1.0, 'Example Data')

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

methods = ["ward", "single", "average", "complete"]
plt.figure(figsize=(20, 10))

for i, linkage_method in enumerate(methods, 1):
    model = AgglomerativeClustering(n_clusters=4, linkage=linkage_method)
    clusters_labels = model.fit_predict(X)

    plt.subplot(2, len(methods), i)
    plt.title(f"{linkage_method.capitalize()} Linkage Dendrogram")
    dendrogram(linkage(X, method=linkage_method), no_labels=True)
    plt.xlabel("Data Points")
    plt.ylabel("Distances")

    plt.subplot(2, len(methods), i + len(methods))
    plt.scatter(X[:, 0], X[:, 1], c=clusters_labels, cmap="viridis")
    plt.title(f"{linkage_method.capitalize()} Linkage Clustering")
    plt.xlabel("X")
    plt.ylabel("Y")

plt.tight_layout()
plt.show()
